# %% [markdown]
# # ASTRA canonical M0 audit
# This notebook executes **M0 only**: exact Drive-object binding, complete SHA-256, ffprobe, sequential decode to EOF, and explicit historical-range decode. It does not run stationarity, selection, CFD, or validation.

# %%
# !rm -rf /content/Turbine-Optimization-CFD
# !git clone -b astra-piv-tournament-v1 --single-branch https://github.com/juanperez238421-cpu/Turbine-Optimization-CFD.git /content/Turbine-Optimization-CFD
# %cd /content/Turbine-Optimization-CFD
# !python -m pip install -q -e piv_tournament
# !python piv_tournament/scripts/astra_colab_m0.py

# %% [markdown]
# A valid completion must print exit code 0 and persist `M0_STATUS.json` with `status: PASS` under `MyDrive/ASTRA_M0_EVIDENCE/<UTC timestamp>/`. Any other outcome leaves M0 closed.
